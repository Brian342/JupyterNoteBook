# %%
import pandas as pd

# %%
s = pd.Series([1,2,3],
             index=['A', 'B', 'C'],
             name='col1')

# %%
data = [[1,4], [2,5], [3,6]]
index = ['A', 'B', 'C']
df1 = pd.DataFrame(data, index=index, columns=['col1', 'col2'])

# %%
df = pd.read_csv("/Users/briankimanzi/Downloads/lung_disease_data.csv", encoding='utf-8')
df
# Out:
#        Age  Gender Smoking Status  Lung Capacity Disease Type Treatment Type  \
# 0     71.0  Female             No           4.49         COPD        Therapy
# 1     34.0  Female            Yes            NaN   Bronchitis        Surgery
# 2     80.0    Male            Yes           1.95         COPD            NaN
# 3     40.0  Female            Yes            NaN   Bronchitis     Medication
# 4     43.0    Male            Yes           4.60         COPD        Surgery
# ...    ...     ...            ...            ...          ...            ...
# 5195  40.0    Male             No           1.43  Lung Cancer     Medication
# 5196  21.0     NaN            Yes           1.50         COPD     Medication
# 5197  42.0  Female             No           5.53    Pneumonia        Surgery
# 5198  82.0    Male             No           3.68   Bronchitis     Medication
# 5199  45.0  Female            Yes           3.79    Pneumonia     Medication
#
#       Hospital Visits Recovered
# ...

# %%
pd.reset_option('display.Max_rows', None)

# %%
df[['Gender', 'Smoking Status', 'Lung Capacity']]
# Out:
#       Gender Smoking Status  Lung Capacity
# 0     Female             No           4.49
# 1     Female            Yes            NaN
# 2       Male            Yes           1.95
# 3     Female            Yes            NaN
# 4       Male            Yes           4.60
# ...      ...            ...            ...
# 5195    Male             No           1.43
# 5196     NaN            Yes           1.50
# 5197  Female             No           5.53
# 5198    Male             No           3.68
# 5199  Female            Yes           3.79
#
# [5200 rows x 3 columns]

# %%
df.iloc[:,[2, 3, 4]] # [index:column]
# Out:
#      Smoking Status  Lung Capacity Disease Type
# 0                No           4.49         COPD
# 1               Yes            NaN   Bronchitis
# 2               Yes           1.95         COPD
# 3               Yes            NaN   Bronchitis
# 4               Yes           4.60         COPD
# ...             ...            ...          ...
# 5195             No           1.43  Lung Cancer
# 5196            Yes           1.50         COPD
# 5197             No           5.53    Pneumonia
# 5198             No           3.68   Bronchitis
# 5199            Yes           3.79    Pneumonia
#
# [5200 rows x 3 columns]

# %%
df.head(20)
# Out:
#      Age  Gender Smoking Status  Lung Capacity Disease Type Treatment Type  \
# 0   71.0  Female             No           4.49         COPD        Therapy
# 1   34.0  Female            Yes            NaN   Bronchitis        Surgery
# 2   80.0    Male            Yes           1.95         COPD            NaN
# 3   40.0  Female            Yes            NaN   Bronchitis     Medication
# 4   43.0    Male            Yes           4.60         COPD        Surgery
# 5   22.0  Female             No           3.65   Bronchitis     Medication
# 6   41.0    Male            Yes           2.98       Asthma     Medication
# 7   72.0    Male            NaN           2.61  Lung Cancer        Surgery
# 8   21.0  Female             No           4.05  Lung Cancer     Medication
# 9   49.0    Male            Yes           5.70    Pneumonia     Medication
# 10  57.0  Female            Yes           4.36   Bronchitis        Therapy
# ...

# %% [markdown]
# # Data Wrangling

# %%
df
# Out:
#        Age  Gender Smoking Status  Lung Capacity Disease Type Treatment Type  \
# 0     71.0  Female             No           4.49         COPD        Therapy
# 1     34.0  Female            Yes            NaN   Bronchitis        Surgery
# 2     80.0    Male            Yes           1.95         COPD            NaN
# 3     40.0  Female            Yes            NaN   Bronchitis     Medication
# 4     43.0    Male            Yes           4.60         COPD        Surgery
# ...    ...     ...            ...            ...          ...            ...
# 5195  40.0    Male             No           1.43  Lung Cancer     Medication
# 5196  21.0     NaN            Yes           1.50         COPD     Medication
# 5197  42.0  Female             No           5.53    Pneumonia        Surgery
# 5198  82.0    Male             No           3.68   Bronchitis     Medication
# 5199  45.0  Female            Yes           3.79    Pneumonia     Medication
#
#       Hospital Visits Recovered
# ...

# %%
df.sort_values(['Age', 'Lung Capacity'],
              ascending=[False, True]) # sorting values in ascending order
# Out:
#        Age  Gender Smoking Status  Lung Capacity Disease Type Treatment Type  \
# 4784  89.0    Male             No           1.02    Pneumonia     Medication
# 1473  89.0  Female             No           1.19  Lung Cancer     Medication
# 3768  89.0  Female             No           1.32         COPD     Medication
# 2203  89.0  Female             No           1.38  Lung Cancer     Medication
# 2775  89.0  Female             No           1.41  Lung Cancer        Therapy
# ...    ...     ...            ...            ...          ...            ...
# 2143   NaN  Female             No            NaN         COPD        Surgery
# 2519   NaN  Female            Yes            NaN         COPD     Medication
# 2942   NaN    Male            Yes            NaN         COPD     Medication
# 3514   NaN  Female            Yes            NaN       Asthma        Therapy
# 4660   NaN  Female             No            NaN    Pneumonia     Medication
#
#       Hospital Visits Recovered
# ...

# %%
df.loc[df.duplicated()] # locates all duplicated values
# Out:
#        Age  Gender Smoking Status  Lung Capacity Disease Type Treatment Type  \
# 5000  83.0  Female             No           3.55         COPD     Medication
# 5005  23.0    Male             No           5.96  Lung Cancer     Medication
# 5006  66.0    Male            Yes           5.24    Pneumonia        Surgery
# 5007  35.0    Male            Yes           4.69   Bronchitis        Therapy
# 5009  31.0    Male             No           5.51    Pneumonia        Therapy
# ...    ...     ...            ...            ...          ...            ...
# 5192  31.0  Female             No           1.51    Pneumonia        Surgery
# 5195  40.0    Male             No           1.43  Lung Cancer     Medication
# 5197  42.0  Female             No           5.53    Pneumonia        Surgery
# 5198  82.0    Male             No           3.68   Bronchitis     Medication
# 5199  45.0  Female            Yes           3.79    Pneumonia     Medication
#
#       Hospital Visits Recovered
# ...

# %%
df = df.transpose()
df = df.T

# %%
df['person']= df['Age']

# %%
df.drop(index= [0, 1, 2])
# Out:
#        Age  Gender Smoking Status  Lung Capacity Disease Type Treatment Type  \
# 3     40.0  Female            Yes            NaN   Bronchitis     Medication
# 4     43.0    Male            Yes           4.60         COPD        Surgery
# 5     22.0  Female             No           3.65   Bronchitis     Medication
# 6     41.0    Male            Yes           2.98       Asthma     Medication
# 7     72.0    Male            NaN           2.61  Lung Cancer        Surgery
# ...    ...     ...            ...            ...          ...            ...
# 5195  40.0    Male             No           1.43  Lung Cancer     Medication
# 5196  21.0     NaN            Yes           1.50         COPD     Medication
# 5197  42.0  Female             No           5.53    Pneumonia        Surgery
# 5198  82.0    Male             No           3.68   Bronchitis     Medication
# 5199  45.0  Female            Yes           3.79    Pneumonia     Medication
#
#       Hospital Visits Recovered
# ...

# %%
clone = df.copy()

# %%
clone
# Out:
#        Age  Gender Smoking Status  Lung Capacity Disease Type Treatment Type  \
# 0     71.0  Female             No           4.49         COPD        Therapy
# 1     34.0  Female            Yes            NaN   Bronchitis        Surgery
# 2     80.0    Male            Yes           1.95         COPD            NaN
# 3     40.0  Female            Yes            NaN   Bronchitis     Medication
# 4     43.0    Male            Yes           4.60         COPD        Surgery
# ...    ...     ...            ...            ...          ...            ...
# 5195  40.0    Male             No           1.43  Lung Cancer     Medication
# 5196  21.0     NaN            Yes           1.50         COPD     Medication
# 5197  42.0  Female             No           5.53    Pneumonia        Surgery
# 5198  82.0    Male             No           3.68   Bronchitis     Medication
# 5199  45.0  Female            Yes           3.79    Pneumonia     Medication
#
#       Hospital Visits Recovered
# ...

# %%
df2 = clone[['Age', 'Lung Capacity']] + 5
pd.concat([df2, clone])
# Out:
#        Age  Lung Capacity  Gender Smoking Status Disease Type Treatment Type  \
# 0     76.0           9.49     NaN            NaN          NaN            NaN
# 1     39.0            NaN     NaN            NaN          NaN            NaN
# 2     85.0           6.95     NaN            NaN          NaN            NaN
# 3     45.0            NaN     NaN            NaN          NaN            NaN
# 4     48.0           9.60     NaN            NaN          NaN            NaN
# ...    ...            ...     ...            ...          ...            ...
# 5195  40.0           1.43    Male             No  Lung Cancer     Medication
# 5196  21.0           1.50     NaN            Yes         COPD     Medication
# 5197  42.0           5.53  Female             No    Pneumonia        Surgery
# 5198  82.0           3.68    Male             No   Bronchitis     Medication
# 5199  45.0           3.79  Female            Yes    Pneumonia     Medication
#
#       Hospital Visits Recovered
# ...

# %%
df3 = pd.DataFrame([[7], [8], [9]], 
                  index=['A', 'B', 'C'],
                  columns=['cols3'])

# %%
df1
# Out:
#    col1  col2
# A     1     4
# B     2     5
# C     3     6

# %%
df1.merge(df3, right_index=True, left_index=True) # inner Join
# Out:
#    col1  col2  cols3
# A     1     4      7
# B     2     5      8
# C     3     6      9

# %%
df.isna().sum() # checks all columns in the dataframe with null values
# Out:
# Age                300
# Gender             300
# Smoking Status     300
# Lung Capacity      300
# Disease Type       300
# Treatment Type     300
# Hospital Visits    300
# Recovered          300
# dtype: int64

# %%
df.fillna(df.bfill())
# Out:
#        Age  Gender Smoking Status  Lung Capacity Disease Type Treatment Type  \
# 0     71.0  Female             No           4.49         COPD        Therapy
# 1     34.0  Female            Yes           1.95   Bronchitis        Surgery
# 2     80.0    Male            Yes           1.95         COPD     Medication
# 3     40.0  Female            Yes           4.60   Bronchitis     Medication
# 4     43.0    Male            Yes           4.60         COPD        Surgery
# ...    ...     ...            ...            ...          ...            ...
# 5195  40.0    Male             No           1.43  Lung Cancer     Medication
# 5196  21.0  Female            Yes           1.50         COPD     Medication
# 5197  42.0  Female             No           5.53    Pneumonia        Surgery
# 5198  82.0    Male             No           3.68   Bronchitis     Medication
# 5199  45.0  Female            Yes           3.79    Pneumonia     Medication
#
#       Hospital Visits Recovered
# ...

# %%
clone
# Out:
#        Age  Gender Smoking Status  Lung Capacity Disease Type Treatment Type  \
# 0     71.0  Female             No           4.49         COPD        Therapy
# 1     34.0  Female            Yes            NaN   Bronchitis        Surgery
# 2     80.0    Male            Yes           1.95         COPD            NaN
# 3     40.0  Female            Yes            NaN   Bronchitis     Medication
# 4     43.0    Male            Yes           4.60         COPD        Surgery
# ...    ...     ...            ...            ...          ...            ...
# 5195  40.0    Male             No           1.43  Lung Cancer     Medication
# 5196  21.0     NaN            Yes           1.50         COPD     Medication
# 5197  42.0  Female             No           5.53    Pneumonia        Surgery
# 5198  82.0    Male             No           3.68   Bronchitis     Medication
# 5199  45.0  Female            Yes           3.79    Pneumonia     Medication
#
#       Hospital Visits Recovered
# ...

# %%
clone['Treatment Type'].unique()
# Out:
# array(['Therapy', 'Surgery', nan, 'Medication'], dtype=object)

# %%
surgery = clone.query('`Treatment Type` == "Surgery"')
# Out:
#        Age  Gender Smoking Status  Lung Capacity Disease Type Treatment Type  \
# 1     34.0  Female            Yes            NaN   Bronchitis        Surgery
# 4     43.0    Male            Yes           4.60         COPD        Surgery
# 7     72.0    Male            NaN           2.61  Lung Cancer        Surgery
# 11    21.0    Male             No           1.37    Pneumonia        Surgery
# 22    34.0    Male             No           3.20    Pneumonia        Surgery
# 25    66.0    Male            NaN           1.17  Lung Cancer        Surgery
# 26    81.0  Female            Yes           3.97    Pneumonia        Surgery
# 33    40.0    Male            Yes           1.73       Asthma        Surgery
# 36    23.0  Female             No           5.77    Pneumonia        Surgery
# 37    79.0  Female             No           1.58    Pneumonia        Surgery
# 39    28.0  Female             No           4.67    Pneumonia        Surgery
# ...

# %%
g = clone.groupby('Age').agg[['mean', 'max', 'min']].sort_values()

# %%
def strsum(group):
    return ''.join([str(x) for x in group.value])

# %%
clone
# Out:
#        Age  Gender Smoking Status  Lung Capacity Disease Type Treatment Type  \
# 0     71.0  Female             No           4.49         COPD        Therapy
# 1     34.0  Female            Yes            NaN   Bronchitis        Surgery
# 2     80.0    Male            Yes           1.95         COPD            NaN
# 3     40.0  Female            Yes            NaN   Bronchitis     Medication
# 4     43.0    Male            Yes           4.60         COPD        Surgery
# 5     22.0  Female             No           3.65   Bronchitis     Medication
# 6     41.0    Male            Yes           2.98       Asthma     Medication
# 7     72.0    Male            NaN           2.61  Lung Cancer        Surgery
# 8     21.0  Female             No           4.05  Lung Cancer     Medication
# 9     49.0    Male            Yes           5.70    Pneumonia     Medication
# 10    57.0  Female            Yes           4.36   Bronchitis        Therapy
# ...

# %%
clone.value_counts()
# Out:
# Age   Gender  Smoking Status  Lung Capacity  Disease Type  Treatment Type  Hospital Visits  Recovered
# 23.0  Female  No              3.79           Lung Cancer   Medication      3.0              No           2
# 47.0  Male    No              5.26           Asthma        Medication      1.0              No           2
# 82.0  Female  No              3.18           Bronchitis    Surgery         5.0              Yes          2
#                               3.16           Bronchitis    Medication      9.0              No           2
# 32.0  Male    No              3.48           Lung Cancer   Therapy         6.0              No           2
# 28.0  Female  No              3.55           Pneumonia     Therapy         12.0             Yes          2
# 87.0  Male    No              2.04           Bronchitis    Medication      6.0              Yes          2
# 47.0  Male    Yes             4.59           Asthma        Therapy         8.0              Yes          2
# ...

# %%
# Numpy
import numpy as np
a = np.array([1,2,3])
c = np.array([10,21,33])

b = np.array([ (1.5,2,3), (4, 5, 6) ], dtype=float)

# %%
d = np.arange(10)

# %%
np.linspace(0,2,9)
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  , 1.25, 1.5 , 1.75, 2.  ])

# %%
e = np.full((1,1), 4)

# %%
np.genfromtxt('/Users/briankimanzi/Downloads/lung_disease_data.csv', delimiter=',')
# Out:
# array([[nan, nan, nan, ..., nan, nan, nan],
#        [71., nan, nan, ..., nan, 14., nan],
#        [34., nan, nan, ..., nan,  7., nan],
#        ...,
#        [42., nan, nan, ..., nan,  5., nan],
#        [82., nan, nan, ..., nan,  9., nan],
#        [45., nan, nan, ..., nan, 10., nan]])

# %%
h = a.view()

# %%
a[a<2] # subsetting
# Out:
# array([1])

# %%
b
# Out:
# array([[1.5, 2. , 3. ],
#        [4. , 5. , 6. ]])

# %%
b
# Out:
# array([[1.5, 2. , 3. ],
#        [4. , 5. , 6. ]])

# %%
print('Hello world')
# Out:
# Hello world
