# %%
print('Hello World')
# Out:
# Hello World

# %% [markdown]
# # Data Types

# %%
int =1
float =2.1
string = " Hello world"
Boolean = True/False

# Arrays
List = []
Dictionary = {'key':True}
set = ()

# %% [markdown]
# # Numerical Operators

# %%
+ addition
- substraction
/ division
** Exponent
% modulas
// floor division
== Equal to
!= Negation
> greater
< less 
>= greater than or equal
<= less than or equal

# %% [markdown]
# # Variable

# %%
message_1 = 'I am learning python'
message_2 = "an it's amazing"
print(f'{message_1} {message_2}')
# Out:
# I am learning python an it's amazing

# %%
Age = input("Enter Your Age: ")
print(int(Age))

# %%
type(Age)
# Out:
# str

# %% [markdown]
# # String methods

# %%
Name = "pyttttthon"
print(Name.replace('t', 'o'))
# Out:
# pyooooohon

# %% [markdown]
# # List

# %%
numbers = [9, 2, 3, 4, 3, 10, 2, 1, 7, 8]

# %%
numbers.insert(0, 100)

# %%
print(dict(numbers))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 print(dict(numbers))
#
# TypeError: cannot convert dictionary update sequence element #0 to a sequence

# %% [markdown]
# # build in functions

# %%
# Out:
# y

# %% [markdown]
# # Dictionaries

# %%
my_data = {'name':'Frank', 'age': 25}
my_data['height'] = 1.7
my_data.update({'height':1.8, 'languages':['English', 'Spaninsh']})
my_data.pop('height')
new_dict = my_data.copy()

# %% [markdown]
# # if statements

# %%
Age = 18
output = 'Can Vote' if Age < 18 else 'Too Young'
print(output)
# Out:
# Too Young

# %%
# Loops
for i, element in enumerate(numbers):
    print(i,element)
# Out:
# 0 9
# 1 2
# 2 3
# 3 4
# 4 3
# 5 10
# 6 2
# 7 1
# 8 7
# 9 8

# %%
def poly(y):
    result = 3*(y**2)+2
    return result
    
print(f'result:{poly(3)}')
# Out:
# result:29

# %%
student = "Philip Oyier"
grades = ["A","B","C","D","D","C"]
gradeDict = {}
gradeDict[student] = grades
print( gradeDict["Philip Oyier"] )
# Out:
# ['A', 'B', 'C', 'D', 'D', 'C']
