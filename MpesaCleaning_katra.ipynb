# %%
import pandas as pd
import numpy as np
from dateutil import parser

# %% [markdown]
# <h2> Reading the dataset </h2>

# %%
# Reading other dataset
Data1 = pd.read_excel('/Users/briankimanzi/Documents/programming Languages/PythonProgramming/JupyterNoteBook/Datasets/MpesaStatement_Katra.xlsx')

# %% [markdown]
# <h2> Cleaning the dataset </h2>

# %%
Data1['Completion Time'] = pd.to_datetime(Data1['Completion Time'])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135 entries, 0 to 134
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Receipt No.         135 non-null    object
#  1   Completion Time     135 non-null    datetime64[ns]
#  2   Details             135 non-null    object
#  3   Transaction Status  135 non-null    object
#  4   Paid In             31 non-null     float64
#  5   Withdrawn           104 non-null    float64
#  6   Balance             135 non-null    float64
# dtypes: datetime64[ns](1), float64(3), object(3)
# memory usage: 7.5+ KB

# %%
# Anonymising the dataset 
def transaction(x):
    x = str(x).strip()
    if x.startswith('Merchant Payment'):
        index = x.find(' - ')+2
        name = x[index:].strip().upper()
        
        return 'BUY GOODS', name

    elif x.startswith('Deposit of Funds'):
        index = x.find(' - ')+2
        name = x[index:].strip().upper()
        
        return 'AGENT DEPOSIT', name

    elif x.startswith('OD Loan Repayment'):
        return 'FULIZA REPAYMENT', 'FULIZA'

    elif x.startswith('OverDraft of Credit Party'):
        return 'FULIZA TAKEN', 'FULUZA'

    elif x.startswith('M-Shwari Deposit'):
        return 'M-SHWARI DEPOSIT FROM M-PESA', 'M-SHWARI'
        
    elif x.startswith('KCB M-PESA Deposit'):
        return 'KCB M-PESA DEPOSIT FROM M-PESA', 'KCB DEPOSIT'

    elif x.startswith('KCB M-PESA Withdraw'):
        return 'KCB M-PESA WITHDRAW FROM M-PESA', 'KCB WITHDRAW'

    elif x.startswith('Customer Transfer'):
        index = x.find(' - ')
        to_search = x[index:]
        last = 1

        for i in range(len(to_search)):
            try:
                int(to_search[i])
                last = i
                
            except:
                v = 10

        name = x[index+last+2:].strip().upper()
        return 'SEND MONEY', name

    elif x.startswith('M-Shwari Withdraw'):
        
        return 'M-SHWARI WITHDRAW FROM M-PESA', 'M-SHWARI WITHDRAW'

    elif x.startswith('Pay Bill Charge'):
        # if x.strip() == 'Pay Bill Charge':
            return 'PAY BILL CHARGES', 'TRANSACTION COST'
        
    elif x.startswith('Pay Bill Online to'):
        if x == 'Pay Bill Online to':  
            return 'PAY BILL ONLINE', 'TRANSACTION COST'
        else:
            start = len('Pay Bill Online to')+8
            end = x.lower().find('acc')
            name = x[start:end].strip().upper()
            return 'PAY BILL', name
    elif x.startswith('Pay Bill'):
        if x == 'Pay Bill':  
            return 'PAY BILL', 'UNKNOWN'
        else:
            start = x.find(' - ') + 3 if ' - ' in x else len('Pay Bill') + 1
            end = x.lower().find('acc')
            name = x[start:end].strip().upper() if end != -1 else x[start:].strip().upper()
            return 'PAY BILL', name

    elif x.startswith('Funds received'):
        index = x.find(' - ')
        to_search = x[index:]
        last = 1

        for i in range(len(to_search)):
            try:
                int(to_search[i])
                last = i
            except:
                v = 10

        name = x[index+last+2:].strip().upper()
        
        return 'RECEIVED FUNDS', name

    elif x.startswith('Customer Payment to Small Business') or x.startswith('Customer Send Money'):
        index = x.find(' - ')
        to_search = x[index:]
        last = 1

        for i in range(len(to_search)):
            try:
                int(to_search[i])
                last = i
            except:
                v = 10

        name = x[index+last+2:].strip().upper()
        
        return 'POCHI LA BIASHARA', name

    elif x.startswith('Airtime Purchase'):
        return 'AIRTIME PURCHASE', 'AIRTIME'

    elif x.startswith('Business Payment From'):
        index = x.find(' - ')
        end = x.lower().find('via')
        to_search = x[index:]
        last = 1
        name = x[index:end].strip().upper()
        return 'FUNDS RECEIVED FROM BUSINESS', name

    elif x.startswith('Customer Transfer of Funds Charge'):
        return 'TRANSACTION COST', 'TRANSACTION COST'
    
    elif x.startswith('Buy Bundles Online'):
        return 'BUNDLES PURCHASE', 'BUNDES PURCHASE'
    
    elif x.startswith('Customer Withdrawal'):
        index = x.find(' - ')+2
        name = x[index:].strip().upper()
        return 'CASH WITHDRAWAL', name
    
    elif x.startswith('Withdrawal Charge'):
        return 'CASH WITHDRAWAL CHARGES', "TRANSACTION COST"

    elif x.startswith('Promotion Payment'):
        return 'PROMOTION PAYMENT', 'M-PESA OFFERS. VIA API'
    
    elif x.startswith('Business Payment'):
        return 'BUSINESS PAYMENT', 'CO-OP BANK VIA API'
        
    elif x.startswith('Savings Contribution'):
        return 'TO HUSTLER FUND SAVINGS', 'HUSTLER FUND'
    
    elif x.startswith('Term Loan Disbursement for H- Fund') or x.startswith('Term Loan Disbursement for H-Fund'):
        return 'HUSTLER FUND Disbursement'.upper(), 'HUSTLER FUND'
    
    elif x.startswith('Term Loan Repayment for H- Fund') or x.startswith('Term Loan Repayment for H-Fund'):
        return 'HUSTLER FUND REPAYMENT', 'HUSTLER FUND'
    
    else:
        return 'UNIDENTIFIED', 'UNIDENTIFIED'

# %%
Data1['Details'] = Data1['Details'].apply(lambda x: x.replace('\r', ' '))

# %%
details = list(Data1['Details'].apply(lambda x: transaction(x)).values)
transactionType = [i[0] for i in details]
TransactionParty = [i[1] for i in details]

# %%
# changing the date format
def change_date(date):
    date_str = str(date)
    date = parser.parse(date_str)
    return (date.year, date.month, date.day, date.weekday(),date.hour, date.minute, date.second)

# %%
date = Data1['Completion Time'].apply(lambda x: change_date(x)).values
Year = [i[0] for i in date]
Month = [i[1] for i in date]
Date = [i[2] for i in date]
Weekday = [i[3] for i in date]
Hour = [i[4] for i in date]
Minute = [i[5] for i in date]
Seconds = [i[6] for i in date]

transactionDay = []

reverseDay = Date.copy()[::-1]
datey = reverseDay[0]

d = 1

for i in reverseDay:
    if i == datey:
        transactionDay.append(d)
    else:
        datey = i
        d += 1
        transactionDay.append(d)

transactionDay.reverse()

# %%
receipt = list(Data1['Receipt No.'].values)

# %%
paid_in = Data1['Paid In'].fillna('NAN_VALUE').values

# %%
def withdrawAmount(x):
    try:
        if x < 0:
            return -x
        else:
            return x
    except:
        return x

# %%
withdraw = list(Data1['Withdrawn'].apply(lambda x: withdrawAmount(x)).values)
withdraw

# %%
transaction_Data = []

for i in range(len(paid_in)):
    try:
        x = float(paid_in[i])
        transaction_Data.append((x, 'PAID IN'))
    except:
        x = float(withdraw[i])
        transaction_Data.append((x, 'WITHDRAW'))

# %%
transaction_amount = [i[0] for i in transaction_Data]
paid_in_or_withdraw = [i[1] for i in transaction_Data]

# %%
balance =list(Data1["Balance"].values)

# %%
katra = pd.DataFrame({
    "Receipt":receipt,
    "transaction_Day": transactionDay,
    "Year" : Year,
    "Month" : Month,
    "Date" : Date,
    "Weekday" : Weekday,
    "Hour" : Hour,
    "Minute" : Minute,
    "Seconds" : Seconds,
    "Transaction_type" : transactionType,
    "Transaction_party" : TransactionParty,
    "Transaction_amount" : transaction_amount,
    "paid_in_or_Withdraw" : paid_in_or_withdraw,
    "Balance" : balance
})
katra.set_index('Receipt', inplace=True)

# %%
# Out:
#         Receipt  transaction_Day  Year  Month  Date  Weekday  Hour  Minute  \
# 0    TD71R8CU5T               68  2025      4     7        0    12      24
# 1    TD48BNDSIK               67  2025      4     4        4     5      10
# 2    TCU0NDJPKK               66  2025      3    30        6     7      13
# 3    TCU0NDJPKK               66  2025      3    30        6     7      13
# 4    TCS0HGRZ5U               65  2025      3    28        4    20       9
# 5    TCS0HGJXSC               65  2025      3    28        4    20       8
# 6    TCP344ZT83               64  2025      3    25        1    20      58
# 7    TCM0NPVBU0               63  2025      3    22        5    12      57
# 8    TCM0NPVBU0               63  2025      3    22        5    12      57
# 9    TCK0EATVUQ               62  2025      3    20        3    10      47
# 10   TCJ1BIKHZZ               61  2025      3    19        2    17      19
# 11   TCJ1BIKHZZ               61  2025      3    19        2    17      19
# 12   TCJ2BG3YTE               61  2025      3    19        2    17       5
# 13   TCI88RDZ2I               60  2025      3    18        1    22       6
# 14   TCI66UNCKK               60  2025      3    18        1    16      11
# 15   TCI95ZYUD7               60  2025      3    18        1    12      38
# 16   TCI95ZYUD7               60  2025      3    18        1    12      38
# 17   TCG6WJ8E0S               59  2025      3    16        6    13      55
# 18   TCE4PF08K6               58  2025      3    14        4    20      20
# 19   TCE5N5UXIB               58  2025      3    14        4    12      57
# 20   TC71RB2E57               57  2025      3     7        4    16      39
# 21   TC52G2OB1S               56  2025      3     5        2     9      39
# 22   TC44BGUFI4               55  2025      3     4        1    10      26
# 23   TC48BESH44               55  2025      3     4        1    10      13
# 24   TC48BEAK3A               55  2025      3     4        1    10      10
# 25   TC10WXWLPC               54  2025      3     1        5    12      47
# 26   TC10WXWLPC               54  2025      3     1        5    12      47
# 27   TC18W3XB4A               54  2025      3     1        5     9      29
# 28   TBP3FJS3XF               53  2025      2    25        1    17      58
# 29   TBP3FJS3XF               53  2025      2    25        1    17      58
# 30   TBO89QPZWG               52  2025      2    24        0    12      25
# 31   TBM9ZFB9KT               51  2025      2    22        5    10       5
# 32   TBL2WSHBPO               50  2025      2    21        4    17      29
# 33   TBL6WS1TWE               50  2025      2    21        4    17      27
# 34   TBL1WOU5RD               50  2025      2    21        4    17       9
# 35   TBL8VR74IG               50  2025      2    21        4    13      24
# 36   TBL0V2DP4U               50  2025      2    21        4    10      30
# 37   TBL0V28676               50  2025      2    21        4    10      29
# 38   TBJ7O4Z84R               49  2025      2    19        2    18      14
# 39   TBJ0NRL68K               49  2025      2    19        2    16      57
# 40   TBJ5NRI3WH               49  2025      2    19        2    16      57
# 41   TBJ9ME9RPR               49  2025      2    19        2    11      13
# 42   TBJ2ME6EBK               49  2025      2    19        2    11      12
# 43   TBH2FI2NHC               48  2025      2    17        0    18      42
# 44   TBF74I8KSJ               47  2025      2    15        5    10      24
# 45   TBB7MB97DF               46  2025      2    11        1    14      42
# 46   TBB4LXYM2C               46  2025      2    11        1    13      12
# 47   TBA4GHQ6E0               45  2025      2    10        0     9      21
# 48   TB631WFXZ7               44  2025      2     6        3    21      36
# 49   TB66ZJXNBA               44  2025      2     6        3    17      58
# 50   TB41NK87J9               43  2025      2     4        1     4      54
# 51   TB47NK5KTP               43  2025      2     4        1     4      48
# 52   TAU51VJSU1               42  2025      1    30        3    10       0
# 53   TAU41UYQ6C               42  2025      1    30        3     9      56
# 54   TAT0ZDOT3G               41  2025      1    29        2    20      20
# 55   TAT0ZDOT3G               41  2025      1    29        2    20      20
# 56   TAT4ZDETY4               41  2025      1    29        2    20      19
# 57   TAT9WKCZQJ               41  2025      1    29        2    10      11
# 58   TAT0WG3MKM               41  2025      1    29        2     9      38
# 59   TAS2S7D8KQ               40  2025      1    28        1     9       2
# 60   TAQ7LSHGYL               39  2025      1    26        6    16      59
# 61   TAN698WKFW               38  2025      1    23        3    17      51
# 62   TAM24535SW               37  2025      1    22        2    13      51
# 63   TAM744T0S7               37  2025      1    22        2    13      49
# 64   TAI7LO8DR9               36  2025      1    18        5    10       8
# 65   TAF6AQWUH6               35  2025      1    15        2    17      37
# 66   TAF28JTXYO               34  2025      1    10        4     9      59
# 67   TA99KF6WRT               33  2025      1     9        3    16      37
# 68   TA75AQPPRR               32  2025      1     7        1    12      33
# 69   TA514QQT7T               31  2025      1     5        6    22      34
# 70   TA524GUKN4               31  2025      1     5        6    21      12
# 71   TA45WVGA83               30  2025      1     4        5    12       2
# 72   TA43WUY65V               30  2025      1     4        5    11      59
# 73   TA40WUTVSU               30  2025      1     4        5    11      58
# 74   TA44VTV60C               30  2025      1     4        5     6      23
# 75   TA36SP48MO               29  2025      1     3        4    11      53
# 76   SLS04HJY7Y               28  2024     12    28        5    11      21
# 77   SLS93VMWXD               28  2024     12    28        5     8      20
# 78   SLJ213V548               27  2024     12    19        3     9      18
# 79   SLJ113OHLF               27  2024     12    19        3     9      17
# 80   SLH4UTD15G               26  2024     12    17        1    22       8
# 81   SLH7TE5ZIB               26  2024     12    17        1    17      46
# 82   SLH7TE5ZIB               26  2024     12    17        1    17      46
# 83   SLH6S8697I               26  2024     12    17        1    13      11
# 84   SL302Y44U6               25  2024     12     3        1    16      24
# 85   SL26W5DOSO               24  2024     12     2        0    10      40
# 86   SL12U0VH6I               23  2024     12     1        6    18      42
# 87   SKU5N7QRHP               22  2024     11    30        5     9       6
# 88   SKU6N7BYAQ               22  2024     11    30        5     9       3
# 89   SKU9N6XQ4H               22  2024     11    30        5     9       0
# 90   SKQ360Y9LX               21  2024     11    26        1    10      15
# 91   SKP44129IK               20  2024     11    25        0    18      51
# 92   SKP93ZEGQP               20  2024     11    25        0    18      44
# 93   SKP83YMSN8               20  2024     11    25        0    18      40
# 94   SKP83YMSN8               20  2024     11    25        0    18      40
# 95   SKP63Y6GIY               20  2024     11    25        0    18      38
# 96   SKP13NJHU9               20  2024     11    25        0    17      44
# 97   SKM3OIYAG1               19  2024     11    22        4    10      23
# 98   SKL0MOBQUC               18  2024     11    21        3    19      18
# 99   SKL9M0ZMLJ               18  2024     11    21        3    17      24
# 100  SKK3GAURMD               17  2024     11    20        2    10      34
# 101  SKK2G2YQFO               17  2024     11    20        2     9      31
# 102  SKJ0F5GJ96               16  2024     11    19        1    21      52
# 103  SKG91EDA1F               15  2024     11    16        5    16      44
# 104  SKG0Z6AMMA               15  2024     11    16        5    11      34
# 105  SKF6WJSZNO               14  2024     11    15        4    17      58
# 106  SKF6WJSZNO               14  2024     11    15        4    17      58
# 107  SKF5WJH3NL               14  2024     11    15        4    17      56
# 108  SKC0LCF4BW               13  2024     11    12        1    22      25
# 109  SK945KREYY               12  2024     11     9        5     9      58
# 110  SK925GTT1M               12  2024     11     9        5     9      29
# 111  SK185RQ9IS               11  2024     11     1        4     8      57
# 112  SK105BBOHW               11  2024     11     1        4     5      41
# 113  SJU6VJB4QA               10  2024     10    30        2     0       7
# 114  SJU9VJ6Y8V               10  2024     10    30        2     0       4
# 115  SJP6DU6IHC                9  2024     10    25        4    19      26
# 116  SJO47UFH1O                8  2024     10    24        3    13       3
# 117  SJO97LUI3Z                8  2024     10    24        3    11      58
# 118  SJO87LBF9A                8  2024     10    24        3    11      54
# 119  SJO87LBF9A                8  2024     10    24        3    11      54
# 120  SJO47IYIB6                8  2024     10    24        3    11      36
# 121  SJN65WBA5I                7  2024     10    23        2    20      46
# 122  SJN45G2KWO                7  2024     10    23        2    19      26
# 123  SJM1YCLW6L                6  2024     10    22        1    12      13
# 124  SJM8Y5AW5C                6  2024     10    22        1    11      15
# 125  SJH6FIH6EG                5  2024     10    17        3    17      49
# 126  SJH6FIH6EG                5  2024     10    17        3    17      49
# 127  SJG3CGPHS5                4  2024     10    16        2    20      43
# 128  SJG0C7HP4K                4  2024     10    16        2    19      52
# 129  SJE222R5O2                3  2024     10    14        0    12      44
# 130  SJC9SXS74T                2  2024     10    12        5    11      49
# 131  SJC9SXS74T                2  2024     10    12        5    11      49
# 132  SJB8QWVJN2                1  2024     10    11        4    19      36
# 133  SJB2QIB142                1  2024     10    11        4    18      34
# 134  SJB3NQVCV5                1  2024     10    11        4     6       0
#
#      Seconds         Transaction_type  \
# 0         25         AIRTIME PURCHASE
# 1         29                 PAY BILL
# 2         23         PAY BILL CHARGES
# 3         23                 PAY BILL
# 4         27         AIRTIME PURCHASE
# 5         25         AIRTIME PURCHASE
# 6         18         AIRTIME PURCHASE
# 7         46         PAY BILL CHARGES
# 8         46                 PAY BILL
# 9         13               SEND MONEY
# 10        24  CASH WITHDRAWAL CHARGES
# 11        24          CASH WITHDRAWAL
# 12         3         BUSINESS PAYMENT
# 13        46           RECEIVED FUNDS
# 14        22         AIRTIME PURCHASE
# 15        51         PAY BILL CHARGES
# 16        51                 PAY BILL
# 17        47               SEND MONEY
# 18        38               SEND MONEY
# 19         6           RECEIVED FUNDS
# 20         6         AIRTIME PURCHASE
# 21        34               SEND MONEY
# 22        49         PAY BILL CHARGES
# 23        34               SEND MONEY
# 24        20               SEND MONEY
# 25        42  CASH WITHDRAWAL CHARGES
# 26        42          CASH WITHDRAWAL
# 27        36         AIRTIME PURCHASE
# 28        38         PAY BILL CHARGES
# 29        38                 PAY BILL
# 30         1         AIRTIME PURCHASE
# 31        54         AIRTIME PURCHASE
# 32        58         AIRTIME PURCHASE
# 33        34         AIRTIME PURCHASE
# 34         2           RECEIVED FUNDS
# 35        21         AIRTIME PURCHASE
# 36        56         AIRTIME PURCHASE
# 37        41         AIRTIME PURCHASE
# 38         1         AIRTIME PURCHASE
# 39        50         AIRTIME PURCHASE
# 40        17         AIRTIME PURCHASE
# 41        24               SEND MONEY
# 42        42         BUSINESS PAYMENT
# 43        46         AIRTIME PURCHASE
# 44         3         AIRTIME PURCHASE
# 45        22           RECEIVED FUNDS
# 46         7               SEND MONEY
# 47        58               SEND MONEY
# 48        38         AIRTIME PURCHASE
# 49        57           RECEIVED FUNDS
# 50        19                 PAY BILL
# 51         1         BUSINESS PAYMENT
# 52        48         AIRTIME PURCHASE
# 53        17         AIRTIME PURCHASE
# 54        26         PAY BILL CHARGES
# 55        26                 PAY BILL
# 56        11         BUSINESS PAYMENT
# 57        35         AIRTIME PURCHASE
# 58        42         AIRTIME PURCHASE
# 59        50         AIRTIME PURCHASE
# 60        37               SEND MONEY
# 61        29           RECEIVED FUNDS
# 62        14         AIRTIME PURCHASE
# 63        14         AIRTIME PURCHASE
# 64        52         AIRTIME PURCHASE
# 65        37         AIRTIME PURCHASE
# 66         1         AIRTIME PURCHASE
# 67        25               SEND MONEY
# 68        21         AIRTIME PURCHASE
# 69        40         AIRTIME PURCHASE
# 70        34                 PAY BILL
# 71        54                 PAY BILL
# 72        20         BUSINESS PAYMENT
# 73        29         AIRTIME PURCHASE
# 74        24           RECEIVED FUNDS
# 75        39               SEND MONEY
# 76        16           RECEIVED FUNDS
# 77        32         AIRTIME PURCHASE
# 78        49               SEND MONEY
# 79        31         AIRTIME PURCHASE
# 80         7         AIRTIME PURCHASE
# 81        37  CASH WITHDRAWAL CHARGES
# 82        37          CASH WITHDRAWAL
# 83         6           RECEIVED FUNDS
# 84        47               SEND MONEY
# 85        44           RECEIVED FUNDS
# 86         8         AIRTIME PURCHASE
# 87        32                 PAY BILL
# 88        19         BUSINESS PAYMENT
# 89        18         AIRTIME PURCHASE
# 90        38         AIRTIME PURCHASE
# 91        27         AIRTIME PURCHASE
# 92        13         AIRTIME PURCHASE
# 93        48         PAY BILL CHARGES
# 94        48                 PAY BILL
# 95        46               SEND MONEY
# 96        14            AGENT DEPOSIT
# 97        30  CASH WITHDRAWAL CHARGES
# 98        16           RECEIVED FUNDS
# 99        51         AIRTIME PURCHASE
# 100       20         AIRTIME PURCHASE
# 101       49               SEND MONEY
# 102       17           RECEIVED FUNDS
# 103       55  CASH WITHDRAWAL CHARGES
# 104        6           RECEIVED FUNDS
# 105       13         PAY BILL CHARGES
# 106       13                 PAY BILL
# 107       32         BUSINESS PAYMENT
# 108        3         AIRTIME PURCHASE
# 109       48                BUY GOODS
# 110        5         AIRTIME PURCHASE
# 111       37           RECEIVED FUNDS
# 112       57         BUSINESS PAYMENT
# 113       59                 PAY BILL
# 114       49         BUSINESS PAYMENT
# 115       12           RECEIVED FUNDS
# 116        1          CASH WITHDRAWAL
# 117       30               SEND MONEY
# 118       28         PAY BILL CHARGES
# 119       28                 PAY BILL
# 120        3           RECEIVED FUNDS
# 121       46        PROMOTION PAYMENT
# 122       56               SEND MONEY
# 123       10          CASH WITHDRAWAL
# 124       34           RECEIVED FUNDS
# 125       58  CASH WITHDRAWAL CHARGES
# 126       58          CASH WITHDRAWAL
# 127       11               SEND MONEY
# 128        3           RECEIVED FUNDS
# 129       18               SEND MONEY
# 130       43         PAY BILL CHARGES
# 131       43                 PAY BILL
# 132       51           RECEIVED FUNDS
# 133       48         BUSINESS PAYMENT
# 134        0         AIRTIME PURCHASE
#
#                                      Transaction_party  Transaction_amount  \
# 0                                              AIRTIME                14.0
# 1                                      SAFARICOM  HOME              3699.0
# 2                                     TRANSACTION COST                10.0
# 3                                         KPLC PREPAID              1000.0
# 4                                              AIRTIME                 5.0
# 5                                              AIRTIME                53.0
# 6                                              AIRTIME               460.0
# 7                                     TRANSACTION COST                10.0
# 8                      PAYSTACK PAYMENTS KENYA LIMITED               646.0
# 9                                      ABDULLAHI SOYAN              2400.0
# 10                                    TRANSACTION COST                29.0
# 11                          GAVY LIMITED JUJA MKT JUJA              2000.0
# 12                                  CO-OP BANK VIA API              5500.0
# 13                                         SAFIA SOYAN              1030.0
# 14                                             AIRTIME               300.0
# 15                                    TRANSACTION COST                 5.0
# 16                                        KPLC PREPAID               500.0
# 17                                       MOHAMED SOYAN              1000.0
# 18                                           DISO BARE              1000.0
# 19                                          NOOR DUKOW              2400.0
# 20                                             AIRTIME               160.0
# 21                                         EBYAN SOYAN               720.0
# 22                                    TRANSACTION COST                10.0
# 23                                      WINFRED MWANGI               300.0
# 24                                         JANE KARIGU             14800.0
# 25                                    TRANSACTION COST               115.0
# 26                          GAVY LIMITED JUJA MKT JUJA              8000.0
# 27                                             AIRTIME               164.0
# 28                                    TRANSACTION COST                10.0
# 29                                        KPLC PREPAID              1000.0
# 30                                             AIRTIME               200.0
# 31                                             AIRTIME               173.0
# 32                                             AIRTIME                 5.0
# 33                                             AIRTIME                20.0
# 34                                          NOOR DUKOW             10120.0
# 35                                             AIRTIME                11.0
# 36                                             AIRTIME                 5.0
# 37                                             AIRTIME               173.0
# 38                                             AIRTIME                20.0
# 39                                             AIRTIME                 5.0
# 40                                             AIRTIME                94.0
# 41                                         MERCY GITAU              3000.0
# 42                                  CO-OP BANK VIA API              3000.0
# 43                                             AIRTIME               200.0
# 44                                             AIRTIME                15.0
# 45                                          NOOR DUKOW               200.0
# 46                                          NOOR DUKOW               200.0
# 47                                         EBYAN SOYAN              1000.0
# 48                                             AIRTIME                55.0
# 49                                     ABDULLAHI SOYAN              3000.0
# 50                                     SAFARICOM  HOME              2775.0
# 51                                  CO-OP BANK VIA API              3699.0
# 52                                             AIRTIME                30.0
# 53                                             AIRTIME                20.0
# 54                                    TRANSACTION COST                10.0
# 55                                        KPLC PREPAID              1000.0
# 56                                  CO-OP BANK VIA API              1000.0
# 57                                             AIRTIME                20.0
# 58                                             AIRTIME                20.0
# 59                                             AIRTIME                20.0
# 60                                         SAFIA SOYAN              1000.0
# 61                                          NOOR DUKOW              1000.0
# 62                                             AIRTIME                 5.0
# 63                                             AIRTIME                31.0
# 64                                             AIRTIME                40.0
# 65                                             AIRTIME                20.0
# 66                                             AIRTIME                25.0
# 67                                         QAMAR SOYAN              1000.0
# 68                                             AIRTIME                30.0
# 69                                             AIRTIME                20.0
# 70                                        KPLC PREPAID              1000.0
# 71                                     SAFARICOM  HOME              3699.0
# 72                                  CO-OP BANK VIA API              3699.0
# 73                                             AIRTIME                10.0
# 74                                         SAFIA SOYAN              2030.0
# 75                                         EBYAN SOYAN              1600.0
# 76                                          NOOR DUKOW              1000.0
# 77                                             AIRTIME                 5.0
# 78                                         QAMAR SOYAN               530.0
# 79                                             AIRTIME                27.0
# 80                                             AIRTIME                20.0
# 81                                    TRANSACTION COST                29.0
# 82    CONRAN INTERNATIONAL PRECIOUS AGENCIES JUJA TOWN              2200.0
# 83                                         SAFIA SOYAN              3055.0
# 84                                         SAFIA SOYAN              1200.0
# 85                                         QAMAR SOYAN              2030.0
# 86                                             AIRTIME                 8.0
# 87                                     SAFARICOM  HOME              3699.0
# 88                                  CO-OP BANK VIA API              3699.0
# 89                                             AIRTIME                 5.0
# 90                                             AIRTIME                 5.0
# 91                                             AIRTIME                10.0
# 92                                             AIRTIME                70.0
# 93                                    TRANSACTION COST                10.0
# 94                                        KPLC PREPAID              1000.0
# 95                                         QAMAR SOYAN               830.0
# 96                           LIONEX LTDJUJA-NEAR JKUAT              2000.0
# 97                                    TRANSACTION COST                29.0
# 98                                         QAMAR SOYAN              1030.0
# 99                                             AIRTIME                14.0
# 100                                            AIRTIME                30.0
# 101                                        QAMAR SOYAN              5000.0
# 102                                        SAFIA SOYAN              5100.0
# 103                                   TRANSACTION COST                29.0
# 104                                        SAFIA SOYAN              1030.0
# 105                                   TRANSACTION COST                 5.0
# 106                                       KPLC PREPAID               450.0
# 107                                 CO-OP BANK VIA API               140.0
# 108                                            AIRTIME                42.0
# 109  ERCHANT PAYMENT TO 7807669 LEILAH WANJIKU MUTONGA              4686.0
# 110                                            AIRTIME                30.0
# 111                                        QAMAR SOYAN              1000.0
# 112                                 CO-OP BANK VIA API              2050.0
# 113                                    SAFARICOM  HOME              3699.0
# 114                                 CO-OP BANK VIA API              3700.0
# 115                                        QAMAR SOYAN              2050.0
# 116             CINCINNATI INVESTMENTS LIMITED UTAWALA              7500.0
# 117                                        SAFIA SOYAN               530.0
# 118                                   TRANSACTION COST                10.0
# 119                                       KPLC PREPAID              1000.0
# 120                                         NOOR DUKOW             10120.0
# 121                             M-PESA OFFERS. VIA API                33.0
# 122                                    ABDULLAHI SOYAN              1600.0
# 123  VIEW POWER COMMS EQUITY ELECTRONICS HILAL GARD...               500.0
# 124                                        SAFIA SOYAN               530.0
# 125                                   TRANSACTION COST                29.0
# 126   CONRAN INTERNATIONAL PRECIOUS AGENCIES JUJA TOWN               290.0
# 127                                        SAFIA SOYAN              3000.0
# 128                                         NOOR DUKOW              3300.0
# 129                                         NOOR DUKOW              3200.0
# 130                                   TRANSACTION COST                 5.0
# 131                                       KPLC PREPAID               500.0
# 132                                        SAFIA SOYAN               500.0
# 133                                 CO-OP BANK VIA API               120.0
# 134                                            AIRTIME                10.0
#
#     paid_in_or_Withdraw   Balance
# 0              WITHDRAW      0.71
# 1              WITHDRAW  96822.71
# 2              WITHDRAW     27.71
# 3              WITHDRAW     37.71
# 4              WITHDRAW   1037.71
# 5              WITHDRAW   1042.71
# 6              WITHDRAW   1095.71
# 7              WITHDRAW   1555.71
# 8              WITHDRAW   1565.71
# 9              WITHDRAW   2244.71
# 10             WITHDRAW   4644.71
# 11             WITHDRAW   4673.71
# 12              PAID IN   6673.71
# 13              PAID IN   1173.71
# 14             WITHDRAW    143.71
# 15             WITHDRAW    443.71
# 16             WITHDRAW    448.71
# 17             WITHDRAW    961.71
# 18             WITHDRAW   1974.71
# 19              PAID IN   3987.71
# 20             WITHDRAW   1587.71
# 21             WITHDRAW   1760.71
# 22             WITHDRAW   2480.71
# 23             WITHDRAW   3497.71
# 24             WITHDRAW   3897.71
# 25             WITHDRAW   1771.71
# 26             WITHDRAW   1886.71
# 27             WITHDRAW   9886.71
# 28             WITHDRAW  10050.71
# 29             WITHDRAW  10060.71
# 30             WITHDRAW  12073.71
# 31             WITHDRAW  12273.71
# 32             WITHDRAW  12446.71
# 33             WITHDRAW  12451.71
# 34              PAID IN  12471.71
# 35             WITHDRAW   2351.71
# 36             WITHDRAW   2362.71
# 37             WITHDRAW   2367.71
# 38             WITHDRAW   2540.71
# 39             WITHDRAW   2560.71
# 40             WITHDRAW   2565.71
# 41             WITHDRAW   2712.71
# 42              PAID IN   5712.71
# 43             WITHDRAW   2712.71
# 44             WITHDRAW   2912.71
# 45              PAID IN   2927.71
# 46             WITHDRAW   2734.71
# 47             WITHDRAW   2947.71
# 48             WITHDRAW   3947.71
# 49              PAID IN   4002.71
# 50             WITHDRAW   1002.71
# 51              PAID IN   3777.71
# 52             WITHDRAW     78.71
# 53             WITHDRAW    108.71
# 54             WITHDRAW    128.71
# 55             WITHDRAW    138.71
# 56              PAID IN   1138.71
# 57             WITHDRAW    138.71
# 58             WITHDRAW    158.71
# 59             WITHDRAW    178.71
# 60             WITHDRAW    211.71
# 61              PAID IN   1211.71
# 62             WITHDRAW    211.71
# 63             WITHDRAW    216.71
# 64             WITHDRAW    247.71
# 65             WITHDRAW    287.71
# 66             WITHDRAW    307.71
# 67             WITHDRAW    365.71
# 68             WITHDRAW   1365.71
# 69             WITHDRAW   1395.71
# 70             WITHDRAW   1425.71
# 71             WITHDRAW   2425.71
# 72              PAID IN   6124.71
# 73             WITHDRAW   2425.71
# 74              PAID IN   2435.71
# 75             WITHDRAW    438.71
# 76              PAID IN   2038.71
# 77             WITHDRAW   1038.71
# 78             WITHDRAW   1056.71
# 79             WITHDRAW   1586.71
# 80             WITHDRAW   1613.71
# 81             WITHDRAW   1633.71
# 82             WITHDRAW   1662.71
# 83              PAID IN   3862.71
# 84             WITHDRAW    830.71
# 85              PAID IN   2030.71
# 86             WITHDRAW      0.71
# 87             WITHDRAW     58.71
# 88              PAID IN   3757.71
# 89             WITHDRAW     58.71
# 90             WITHDRAW     63.71
# 91             WITHDRAW     68.71
# 92             WITHDRAW     78.71
# 93             WITHDRAW    148.71
# 94             WITHDRAW    158.71
# 95             WITHDRAW   1171.71
# 96              PAID IN   2001.71
# 97             WITHDRAW      1.71
# 98              PAID IN   1030.71
# 99             WITHDRAW      0.71
# 100            WITHDRAW     14.71
# 101            WITHDRAW    101.71
# 102             PAID IN   5101.71
# 103            WITHDRAW      1.71
# 104             PAID IN   1030.71
# 105            WITHDRAW      0.71
# 106            WITHDRAW      5.71
# 107             PAID IN    455.71
# 108            WITHDRAW    315.71
# 109            WITHDRAW    357.71
# 110            WITHDRAW   5043.71
# 111             PAID IN   6073.71
# 112             PAID IN   5073.71
# 113            WITHDRAW   3023.71
# 114             PAID IN   6722.71
# 115             PAID IN   3022.71
# 116            WITHDRAW   1109.71
# 117            WITHDRAW   8622.71
# 118            WITHDRAW   9152.71
# 119            WITHDRAW   9162.71
# 120             PAID IN  10162.71
# 121             PAID IN     42.71
# 122            WITHDRAW     42.71
# 123            WITHDRAW     31.71
# 124             PAID IN    531.71
# 125            WITHDRAW      1.71
# 126            WITHDRAW     30.71
# 127            WITHDRAW    373.71
# 128             PAID IN   3373.71
# 129            WITHDRAW    126.71
# 130            WITHDRAW    126.71
# 131            WITHDRAW    131.71
# 132             PAID IN    631.71
# 133             PAID IN    131.71
# 134            WITHDRAW     11.71
