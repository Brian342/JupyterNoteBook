# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/briankimanzi/Documents/Excel/netflix1_python.csv', encoding='ISO-8859-1')
df
# Out:
#      Show_id_cleaning     type  Unnamed: 2  \
# 0               ss307    Movie        76.0
# 1              ss5968    Movie         NaN
# 2              ss4668    Movie         NaN
# 3              ss5969    Movie         NaN
# 4              ss5970    Movie         NaN
# ...               ...      ...         ...
# 8785           ss1833    Movie         NaN
# 8786           ss8807    Movie         NaN
# 8787           ss1957    Movie         NaN
# 8788           ss1774  TV Show         NaN
# 8789           ss2867    Movie         NaN
#
#        Title_cleaning_Removing_Special_Cases           director  \
# 0                                         76         Izu Ojukwu
# 1                                         89          Not Given
# 2                       ââKuch Bheege Alfaaz               Onir
# 3                               âGoli Soda 2       Vijay Milton
# 4                         âMaj Rati ââKeteki  Santwana Bardoloi
# ...

# %%
rows, columns  = df.shape
print(f'rows: {rows} columns: {columns}')
# Out:
# rows: 8790 columns: 23

# %%
# reading columns
df.columns
# Out:
# Index(['Show_id_cleaning', 'type', 'Unnamed: 2',
#        'Title_cleaning_Removing_Special_Cases', 'director', 'country',
#        'date_added', 'release_year', 'rating', 'duration', 'listed_in',
#        'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14',
#        'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18',
#        'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22'],
#       dtype='object')

# %%
# df.set_index('Show_id_cleaning', inplace=True)
df.reset_index(inplace=True)
df
# Out:
#       index Show_id_cleaning     type  Unnamed: 2  \
# 0         0            ss307    Movie        76.0
# 1         1           ss5968    Movie         NaN
# 2         2           ss4668    Movie         NaN
# 3         3           ss5969    Movie         NaN
# 4         4           ss5970    Movie         NaN
# ...     ...              ...      ...         ...
# 8785   8785           ss1833    Movie         NaN
# 8786   8786           ss8807    Movie         NaN
# 8787   8787           ss1957    Movie         NaN
# 8788   8788           ss1774  TV Show         NaN
# 8789   8789           ss2867    Movie         NaN
#
#        Title_cleaning_Removing_Special_Cases           director  \
# 0                                         76         Izu Ojukwu
# 1                                         89          Not Given
# 2                       ââKuch Bheege Alfaaz               Onir
# 3                               âGoli Soda 2       Vijay Milton
# ...

# %%
df['Show_id_cleaning'].sort_values()
# Out:
# 1963       ss1
# 7768      ss10
# 5206     ss100
# 6574    ss1000
# 8602    ss1001
#          ...
# 7958     ss995
# 8396     ss996
# 3127     ss997
# 4055     ss998
# 6136     ss999
# Name: Show_id_cleaning, Length: 8790, dtype: object

# %%
df['Numerical_part'] = df['Show_id_cleaning'].str.extract(r'(\d+)').astype(int)
df = df.sort_values(by='Numerical_part').drop(columns='Numerical_part')
df
# Out:
#       index Show_id_cleaning     type  Unnamed: 2  \
# 1963   1963              ss1    Movie         NaN
# 1077   1077              ss2  TV Show         NaN
# 2630   2630              ss3  TV Show         NaN
# 3491   3491              ss4  TV Show         NaN
# 3850   3850              ss5  TV Show         NaN
# ...     ...              ...      ...         ...
# 8776   8776           ss8803    Movie         NaN
# 8779   8779           ss8804  TV Show         NaN
# 8780   8780           ss8805    Movie         NaN
# 8783   8783           ss8806    Movie         NaN
# 8786   8786           ss8807    Movie         NaN
#
#      Title_cleaning_Removing_Special_Cases         director        country  \
# 1963                  Dick Johnson Is Dead  Kirsten Johnson  United States
# 1077                         Blood & Water        Not Given   South Africa
# 2630                             Ganglands  Julien Leclercq         France
# ...

# %%
# setting the Show_id_cleaning as the index
df.set_index('Show_id_cleaning', inplace=True)
df
# Out:
#                   index     type  Unnamed: 2  \
# Show_id_cleaning
# ss1                1963    Movie         NaN
# ss2                1077  TV Show         NaN
# ss3                2630  TV Show         NaN
# ss4                3491  TV Show         NaN
# ss5                3850  TV Show         NaN
# ...                 ...      ...         ...
# ss8803             8776    Movie         NaN
# ss8804             8779  TV Show         NaN
# ss8805             8780    Movie         NaN
# ss8806             8783    Movie         NaN
# ss8807             8786    Movie         NaN
#
#                  Title_cleaning_Removing_Special_Cases         director  \
# Show_id_cleaning
# ss1                               Dick Johnson Is Dead  Kirsten Johnson
# ss2                                      Blood & Water        Not Given
# ss3                                          Ganglands  Julien Leclercq
# ss4                              Jailbirds New Orleans        Not Given
# ...

# %%
df.drop(columns='Unnamed: 2', inplace=True)

# %%
# Removing special characters on the title_cleaning_removing_special_case
import re
df['Title_cleaning_Removing_Special_Cases'] = df['Title_cleaning_Removing_Special_Cases'].str.replace(r'[^a-zA-Z0-9]', '', regex=True)

# %%
# Director column
df['director'] = df['director'].str.replace(r'[^a-zA-Z0-9]', '', regex=True)

# %%
df['country']
# Out:
# Show_id_cleaning
# ss1       United States
# ss2        South Africa
# ss3              France
# ss4            Pakistan
# ss5               India
#               ...
# ss8803    United States
# ss8804         Pakistan
# ss8805    United States
# ss8806    United States
# ss8807            India
# Name: country, Length: 8790, dtype: object

# %%
country_grp = df.groupby(['country'])

# %%
df.isna().sum()
# Out:
# index                                    0
# type                                     0
# Title_cleaning_Removing_Special_Cases    0
# director                                 0
# country                                  0
# date_added                               0
# release_year                             0
# rating                                   0
# duration                                 0
# listed_in                                0
# Year_added                               0
# Minutes                                  0
# Seasons                                  0
# dtype: int64

# %%
# replacing all the null values with 0
df['Minutes'] = df['Minutes'].fillna(0)

# %%
df.dtypes
# Out:
# index                                             int64
# type                                             object
# Title_cleaning_Removing_Special_Cases            object
# director                                         object
# country                                          object
# date_added                               datetime64[ns]
# release_year                                      int64
# rating                                           object
# duration                                         object
# listed_in                                        object
# Year_added                                        int32
# Minutes                                          object
# Seasons                                          object
# dtype: object

# %%
country_grp['type'].value_counts().loc['India']
# Out:
# type
# Movie      976
# TV Show     81
# Name: count, dtype: int64

# %%
# date column
df['date_added'] = pd.to_datetime(df['date_added'], format=None)

# %%
# creating a new column that will contain the year only
df['Year_added'] = df['date_added'].dt.year

# %%
# rearranging columns on the data set
rea = df[cols[0:5] + [cols[-1]] + cols[5:20]]
df = rea
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 2
#       1 # rearranging columns on the data set
# ----> 2 rea = df[cols[0:5] + [cols[-1]] + cols[5:20]]
#       3 df = rea
#
# NameError: name 'cols' is not defined

# %%
df

# %%
# returns all columns containing min
df.loc[df['duration'].str.contains('min')]
# Out:
#                   index   type Title_cleaning_Removing_Special_Cases  \
# Show_id_cleaning
# ss1                1963  Movie                     DickJohnsonIsDead
# ss7                4860  Movie            MyLittlePonyANewGeneration
# ss8                6055  Movie                               Sankofa
# ss10               7768  Movie                           TheStarling
# ss13               3514  Movie                            JeSuisKarl
# ...                 ...    ...                                   ...
# ss8802             8772  Movie                               Zinzana
# ss8803             8776  Movie                                Zodiac
# ss8805             8780  Movie                            Zombieland
# ss8806             8783  Movie                                  Zoom
# ss8807             8786  Movie                                Zubaan
#
#                                  director               country date_added  \
# Show_id_cleaning
# ...

# %%
df['Minutes']=df['duration'].str.extract(r'(\d+)\s*min\b')[0].dropna().astype(int).astype(str) + ' Min'

# %%
df
# Out:
#                   index     type Title_cleaning_Removing_Special_Cases  \
# Show_id_cleaning
# ss1                1963    Movie                     DickJohnsonIsDead
# ss2                1077  TV Show                            BloodWater
# ss3                2630  TV Show                             Ganglands
# ss4                3491  TV Show                   JailbirdsNewOrleans
# ss5                3850  TV Show                           KotaFactory
# ...                 ...      ...                                   ...
# ss8803             8776    Movie                                Zodiac
# ss8804             8779  TV Show                            ZombieDumb
# ss8805             8780    Movie                            Zombieland
# ss8806             8783    Movie                                  Zoom
# ss8807             8786    Movie                                Zubaan
#
#                         director        country date_added  release_year  \
# Show_id_cleaning
# ...

# %%
cols = list(df.columns)
Min_arr = df[cols[0:9] + [cols[-1]] + cols[9:20]]
Min_arr
# Out:
#                   index     type Title_cleaning_Removing_Special_Cases  \
# Show_id_cleaning
# ss1                1963    Movie                     DickJohnsonIsDead
# ss2                1077  TV Show                            BloodWater
# ss3                2630  TV Show                             Ganglands
# ss4                3491  TV Show                   JailbirdsNewOrleans
# ss5                3850  TV Show                           KotaFactory
# ...                 ...      ...                                   ...
# ss8803             8776    Movie                                Zodiac
# ss8804             8779  TV Show                            ZombieDumb
# ss8805             8780    Movie                            Zombieland
# ss8806             8783    Movie                                  Zoom
# ss8807             8786    Movie                                Zubaan
#
#                         director        country date_added  release_year  \
# Show_id_cleaning
# ...

# %%
# seasons
# df['duration'] = df['duration'].str.replace(r'\bSeason\b', 'Seasons', regex=True) # normalizing the season to seasons
df['Seasons'] = df['duration'].str.extract(r'(\d+)\s*Seasons\b').dropna().fillna(0).astype(int).astype(str) + ' Seasons'

# %%
df

# %%
colun = list(df.columns)
sea_arr = df[colun[0:8] + [colun[-1]] + colun[8:20]]
sea_arr
# Out:
#                   index     type Title_cleaning_Removing_Special_Cases  \
# Show_id_cleaning
# ss1                1963    Movie                     DickJohnsonIsDead
# ss2                1077  TV Show                            BloodWater
# ss3                2630  TV Show                             Ganglands
# ss4                3491  TV Show                   JailbirdsNewOrleans
# ss5                3850  TV Show                           KotaFactory
# ...                 ...      ...                                   ...
# ss8803             8776    Movie                                Zodiac
# ss8804             8779  TV Show                            ZombieDumb
# ss8805             8780    Movie                            Zombieland
# ss8806             8783    Movie                                  Zoom
# ss8807             8786    Movie                                Zubaan
#
#                         director        country date_added  release_year  \
# Show_id_cleaning
# ...

# %%
# droping unnecessary columns
df.drop(['Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 
        'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 
        'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20'],
       axis=1, inplace=True)

# %%
df.drop('Unnamed: 22', axis=1, inplace=True)

# %%
# listed in column
listed_in_grp = df.groupby('listed_in')

# %%
listed_in_grp.get_group('')

# %%
listed_in_grp['listed_in'].loc['Dramas']

# %%
df.to_csv('NetflixCleaned.csv')

# %%
df
# Out:
#                   index     type Title_cleaning_Removing_Special_Cases  \
# Show_id_cleaning
# ss1                1963    Movie                     DickJohnsonIsDead
# ss2                1077  TV Show                            BloodWater
# ss3                2630  TV Show                             Ganglands
# ss4                3491  TV Show                   JailbirdsNewOrleans
# ss5                3850  TV Show                           KotaFactory
# ...                 ...      ...                                   ...
# ss8803             8776    Movie                                Zodiac
# ss8804             8779  TV Show                            ZombieDumb
# ss8805             8780    Movie                            Zombieland
# ss8806             8783    Movie                                  Zoom
# ss8807             8786    Movie                                Zubaan
#
#                         director        country date_added  release_year  \
# Show_id_cleaning
# ...
