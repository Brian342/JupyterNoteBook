# %%
import pandas as pd

# %% [markdown]
# <h2> Reading the dataset </h2>

# %%
# Reading other dataset
Data1 = pd.read_excel('/Users/briankimanzi/Documents/programming Languages/PythonProgramming/JupyterNoteBook/Datasets/MpesaStatement_Katra.xlsx')
Data2 = pd.read_excel('/Users/briankimanzi/Documents/programming Languages/PythonProgramming/JupyterNoteBook/Datasets/MPESA_Marylyne.xlsx')

# %% [markdown]
# <h2> Cleaning the dataset </h2>

# %%
Data1
# Out:
#     Receipt No.     Completion Time  \
# 0    TD71R8CU5T 2025-04-07 12:24:25
# 1    TD48BNDSIK 2025-04-04 05:10:29
# 2    TCU0NDJPKK 2025-03-30 07:13:23
# 3    TCU0NDJPKK 2025-03-30 07:13:23
# 4    TCS0HGRZ5U 2025-03-28 20:09:27
# ..          ...                 ...
# 130  SJC9SXS74T 2024-10-12 11:49:43
# 131  SJC9SXS74T 2024-10-12 11:49:43
# 132  SJB8QWVJN2 2024-10-11 19:36:51
# 133  SJB2QIB142 2024-10-11 18:34:48
# 134  SJB3NQVCV5 2024-10-11 06:00:00
#
#                                                Details Transaction Status  \
# 0                                     Airtime Purchase          Completed
# 1    Pay Bill Online to 522006 SAFARICOM  HOME Acc....          Completed
# 2                                      Pay Bill Charge          Completed
# 3    Pay Bill to 888880 - KPLC PREPAID Acc. 3722768...          Completed
# 4                                     Airtime Purchase          Completed
# ..                                                 ...                ...
# 130                                    Pay Bill Charge          Completed
# 131  Pay Bill to 888880 - KPLC PREPAID Acc. 3722768...          Completed
# 132    Funds received from - 2547******829 SAFIA SOYAN          Completed
# 133  Business Payment from 149444 CO-OP BANK via AP...          Completed
# 134                                   Airtime Purchase          Completed
#
#      Paid In  Withdrawn   Balance
# 0        NaN      -14.0      0.71
# 1        NaN    -3699.0  96822.71
# 2        NaN      -10.0     27.71
# 3        NaN    -1000.0     37.71
# 4        NaN       -5.0   1037.71
# ..       ...        ...       ...
# 130      NaN       -5.0    126.71
# 131      NaN     -500.0    131.71
# 132    500.0        NaN    631.71
# 133    120.0        NaN    131.71
# 134      NaN      -10.0     11.71
#
# [135 rows x 7 columns]

# %%
# Anonymising the dataset 
def transaction(x):
    x = str(x).strip()
    if x.startswith('Merchant Payment'):
        index = x.find(' - ')+2
        name = x[index:].strip().upper()
        
        return 'BUY GOODS', name

    elif x.startswith('Deposit of funds'):
        index = x.find(' - ')
        name = x[index:].strip().upper()
        
        return 'AGENT DEPOSIT', name

    elif x.startswith('OD Loan Repayment'):
        return 'FULIZA REPAYMENT', 'FULIZA'

    elif x.startswith('OverDraft of Credit Party'):
        return 'FULIZA TAKEN', 'FULUZA'

    elif x.startswith('M-Shwari Deposit'):
        return 'M-SHWARI DEPOSIT FROM M-PESA', 'M-SHWARI'
        
    elif x.startswith('KCB M-PESA Deposit'):
        return 'KCB M-PESA DEPOSIT FROM M-PESA', 'KCB DEPOSIT'

    elif x.startswith('KCB M-PESA Withdraw'):
        return 'KCB M-PESA WITHDRAW FROM M-PESA', 'KCB WITHDRAW'

    elif x.startswith('Customer Transfer'):
        index = x.find(' - ')
        to_search = x[index:]
        last = 1

        for i in range(len(to_search)):
            try:
                int(to_search[i])
                last = i
                
            except:
                v = 10

        name = x[index+last+2:].strip().upper()
        return 'SEND MONEY', name

    elif x.startswith('M-Shwari Withdraw'):
        
        return 'M-SHWARI WITHDRAW FROM M-PESA', 'M-SHWARI WITHDRAW'

    elif x.startswith('Pay Bill Charge'):
        # if x.strip() == 'Pay Bill Charge':
            return 'PAY BILL CHARGES', 'TRANSACTION COST'
    elif x.startswith('Pay Bill Online to'):
        if x == 'Pay Bill Online to':  # if there's nothing after
            return 'PAY BILL ONLINE', 'TRANSACTION COST'
        else:
            # Find the part after "Pay Bill Online to" and before "Acc"
            start = len('Pay Bill Online to') + 1
            end = x.lower().find('acc')
            name = x[start:end].strip().upper()
            return 'PAY BILL', name
     elif x.startswith('Pay Bill'):
        if x == 'Pay Bill':  # if there's nothing after
            return 'PAY BILL', 'UNKNOWN'
        else:
            # Find the part after " - " and before "Acc"
            start = x.find(' - ') + 3 if ' - ' in x else len('Pay Bill') + 1
            end = x.lower().find('acc')
            name = x[start:end].strip().upper() if end != -1 else x[start:].strip().upper()
            return 'PAY BILL', name
            
        # else:
        #     index = x.find(' - ')+3
        #     end = x.lower().find('acc')
        #     name = x[index:end].strip().upper()
            
        #     return 'PAY BILL', name

    elif x.startswith('Funds received'):
        index = x.find(' - ')
        to_search = x[index:]
        last = 1

        for i in range(len(to_search)):
            try:
                int(to_search[i])
                last = i
            except:
                v = 10

        name = x[index+last+2:].strip().upper()
        
        return 'RECEIVED FUNDS', name

    elif x.startswith('Customer Payment to Small Business') or x.startswith('Customer Send Money'):
        index = x.find(' - ')
        to_search = x[index:]
        last = 1

        for i in range(len(to_search)):
            try:
                int(to_search[i])
                last = i
            except:
                v = 10

        name = x[index+last+2:].strip().upper()
        
        return 'POCHI LA BIASHARA', name

    elif x.startswith('Airtime Purchase'):
        return 'AIRTIME PURCHASE', 'AIRTIME'

    elif x.startswith('Business Payment From'):
        index = x.find(' - ')
        end = x.lower().find('via')
        to_search = x[index:]
        last = 1
        name = x[index:end].strip().upper()
        return 'FUNDS RECEIVED FROM BUSINESS', name

    elif x.startswith('Customer Transfer of Funds Charge'):
        return 'TRANSACTION COST', 'TRANSACTION COST'
    
    elif x.startswith('Buy Bundles Online'):
        return 'BUNDLES PURCHASE', 'BUNDES PURCHASE'
    
    elif x.startswith('Customer Withdrawal'):
        index = x.find(' - ')
        name = x[index:].strip().upper()
        return 'CASH WITHDRAWAL', name
    
    elif x.startswith('Withdrawal Charge'):
        return 'CASH WITHDRAWAL CHARGES', "TRANSACTION COST"
    
    elif x.startswith('Savings Contribution'):
        return 'TO HUSTLER FUND SAVINGS', 'HUSTLER FUND'
    
    elif x.startswith('Term Loan Disbursement for H- Fund') or x.startswith('Term Loan Disbursement for H-Fund'):
        return 'HUSTLER FUND Disbursement'.upper(), 'HUSTLER FUND'
    
    elif x.startswith('Term Loan Repayment for H- Fund') or x.startswith('Term Loan Repayment for H-Fund'):
        return 'HUSTLER FUND REPAYMENT', 'HUSTLER FUND'
    
    else:
        return 'UNIDENTIFIED', 'UNIDENTIFIED'

# %%
Data1['Details'] = Data1['Details'].apply(lambda x: x.replace('\r', ' '))

# %%
details = list(Data1['Details'].apply(lambda x: transaction(x)).values)
transactionType = [i[0] for i in details]
TransactionParty = [i[1] for i in details]

# %%
TransactionParty
# Out:
# ['AIRTIME',
#  'Y BILL ONLINE TO 522006 SAFARICOM  HOME',
#  'TRANSACTION COST',
#  'KPLC PREPAID',
#  'AIRTIME',
#  'AIRTIME',
#  'AIRTIME',
#  'TRANSACTION COST',
#  'Y BILL ONLINE TO 4103879 PAYSTACK PAYMENTS KENYA LIMITED',
#  'STOMER TRANSFER TO -2547******581 ABDULLAHI SOYAN',
#  'TRANSACTION COST',
#  '- GAVY LIMITED JUJA MKT JUJA',
#  'UNIDENTIFIED',
#  'SAFIA SOYAN',
#  'AIRTIME',
#  'TRANSACTION COST',
#  'KPLC PREPAID',
#  'MOHAMED SOYAN',
#  'DISO BARE',
#  'NOOR DUKOW',
#  'AIRTIME',
#  'EBYAN SOYAN',
#  'TRANSACTION COST',
#  'WINFRED MWANGI',
#  'JANE KARIGU',
#  'TRANSACTION COST',
#  '- GAVY LIMITED JUJA MKT JUJA',
#  'AIRTIME',
#  'TRANSACTION COST',
#  'KPLC PREPAID',
#  'AIRTIME',
#  'AIRTIME',
#  'AIRTIME',
#  'AIRTIME',
#  'NOOR DUKOW',
#  'AIRTIME',
#  'AIRTIME',
#  'AIRTIME',
#  'AIRTIME',
#  'AIRTIME',
#  'AIRTIME',
#  'MERCY GITAU',
#  'UNIDENTIFIED',
#  'AIRTIME',
#  'AIRTIME',
#  'NOOR DUKOW',
#  'NOOR DUKOW',
#  'EBYAN SOYAN',
#  'AIRTIME',
#  'ABDULLAHI SOYAN',
#  'Y BILL ONLINE TO 522006 SAFARICOM  HOME',
#  'UNIDENTIFIED',
#  'AIRTIME',
#  'AIRTIME',
#  'TRANSACTION COST',
#  'KPLC PREPAID',
#  'UNIDENTIFIED',
#  'AIRTIME',
#  'AIRTIME',
#  'AIRTIME',
#  'SAFIA SOYAN',
#  'NOOR DUKOW',
#  'AIRTIME',
#  'AIRTIME',
#  'AIRTIME',
#  'AIRTIME',
#  'AIRTIME',
#  'QAMAR SOYAN',
#  'AIRTIME',
#  'AIRTIME',
#  'KPLC PREPAID',
#  'Y BILL ONLINE TO 522006 SAFARICOM  HOME',
#  'UNIDENTIFIED',
#  'AIRTIME',
#  'SAFIA SOYAN',
#  'EBYAN SOYAN',
#  'NOOR DUKOW',
#  'AIRTIME',
#  'QAMAR SOYAN',
#  'AIRTIME',
#  'AIRTIME',
#  'TRANSACTION COST',
#  '- CONRAN INTERNATIONAL PRECIOUS AGENCIES JUJA TOWN',
#  'SAFIA SOYAN',
#  'SAFIA SOYAN',
#  'QAMAR SOYAN',
#  'AIRTIME',
#  'Y BILL ONLINE TO 522006 SAFARICOM  HOME',
#  'UNIDENTIFIED',
#  'AIRTIME',
#  'AIRTIME',
#  'AIRTIME',
#  'AIRTIME',
#  'TRANSACTION COST',
#  'KPLC PREPAID',
#  'QAMAR SOYAN',
#  'UNIDENTIFIED',
#  'TRANSACTION COST',
#  'QAMAR SOYAN',
#  'AIRTIME',
#  'AIRTIME',
#  'QAMAR SOYAN',
#  'SAFIA SOYAN',
#  'TRANSACTION COST',
#  'SAFIA SOYAN',
#  'TRANSACTION COST',
#  'KPLC PREPAID',
#  'UNIDENTIFIED',
#  'AIRTIME',
#  'ERCHANT PAYMENT TO 7807669 LEILAH WANJIKU MUTONGA',
#  'AIRTIME',
#  'QAMAR SOYAN',
#  'UNIDENTIFIED',
#  'Y BILL ONLINE TO 522006 SAFARICOM  HOME',
#  'UNIDENTIFIED',
#  'QAMAR SOYAN',
#  '- CINCINNATI INVESTMENTS LIMITED UTAWALA',
#  'SAFIA SOYAN',
#  'TRANSACTION COST',
#  'KPLC PREPAID',
#  'NOOR DUKOW',
#  'UNIDENTIFIED',
#  'ABDULLAHI SOYAN',
#  '- VIEW POWER COMMS EQUITY ELECTRONICS HILAL GARDEN HOTEL',
#  'SAFIA SOYAN',
#  'TRANSACTION COST',
#  '- CONRAN INTERNATIONAL PRECIOUS AGENCIES JUJA TOWN',
#  'SAFIA SOYAN',
#  'NOOR DUKOW',
#  'NOOR DUKOW',
#  'TRANSACTION COST',
#  'KPLC PREPAID',
#  'SAFIA SOYAN',
#  'UNIDENTIFIED',
#  'AIRTIME']

# %%
transactionType
# Out:
# ['AIRTIME PURCHASE',
#  'PAY BILL',
#  'PAY BILL CHARGES',
#  'PAY BILL',
#  'AIRTIME PURCHASE',
#  'AIRTIME PURCHASE',
#  'AIRTIME PURCHASE',
#  'PAY BILL CHARGES',
#  'PAY BILL',
#  'SEND MONEY',
#  'CASH WITHDRAWAL CHARGES',
#  'CASH WITHDRAWAL',
#  'UNIDENTIFIED',
#  'RECEIVED FUNDS',
#  'AIRTIME PURCHASE',
#  'PAY BILL CHARGES',
#  'PAY BILL',
#  'SEND MONEY',
#  'SEND MONEY',
#  'RECEIVED FUNDS',
#  'AIRTIME PURCHASE',
#  'SEND MONEY',
#  'PAY BILL CHARGES',
#  'SEND MONEY',
#  'SEND MONEY',
#  'CASH WITHDRAWAL CHARGES',
#  'CASH WITHDRAWAL',
#  'AIRTIME PURCHASE',
#  'PAY BILL CHARGES',
#  'PAY BILL',
#  'AIRTIME PURCHASE',
#  'AIRTIME PURCHASE',
#  'AIRTIME PURCHASE',
#  'AIRTIME PURCHASE',
#  'RECEIVED FUNDS',
#  'AIRTIME PURCHASE',
#  'AIRTIME PURCHASE',
#  'AIRTIME PURCHASE',
#  'AIRTIME PURCHASE',
#  'AIRTIME PURCHASE',
#  'AIRTIME PURCHASE',
#  'SEND MONEY',
#  'UNIDENTIFIED',
#  'AIRTIME PURCHASE',
#  'AIRTIME PURCHASE',
#  'RECEIVED FUNDS',
#  'SEND MONEY',
#  'SEND MONEY',
#  'AIRTIME PURCHASE',
#  'RECEIVED FUNDS',
#  'PAY BILL',
#  'UNIDENTIFIED',
#  'AIRTIME PURCHASE',
#  'AIRTIME PURCHASE',
#  'PAY BILL CHARGES',
#  'PAY BILL',
#  'UNIDENTIFIED',
#  'AIRTIME PURCHASE',
#  'AIRTIME PURCHASE',
#  'AIRTIME PURCHASE',
#  'SEND MONEY',
#  'RECEIVED FUNDS',
#  'AIRTIME PURCHASE',
#  'AIRTIME PURCHASE',
#  'AIRTIME PURCHASE',
#  'AIRTIME PURCHASE',
#  'AIRTIME PURCHASE',
#  'SEND MONEY',
#  'AIRTIME PURCHASE',
#  'AIRTIME PURCHASE',
#  'PAY BILL',
#  'PAY BILL',
#  'UNIDENTIFIED',
#  'AIRTIME PURCHASE',
#  'RECEIVED FUNDS',
#  'SEND MONEY',
#  'RECEIVED FUNDS',
#  'AIRTIME PURCHASE',
#  'SEND MONEY',
#  'AIRTIME PURCHASE',
#  'AIRTIME PURCHASE',
#  'CASH WITHDRAWAL CHARGES',
#  'CASH WITHDRAWAL',
#  'RECEIVED FUNDS',
#  'SEND MONEY',
#  'RECEIVED FUNDS',
#  'AIRTIME PURCHASE',
#  'PAY BILL',
#  'UNIDENTIFIED',
#  'AIRTIME PURCHASE',
#  'AIRTIME PURCHASE',
#  'AIRTIME PURCHASE',
#  'AIRTIME PURCHASE',
#  'PAY BILL CHARGES',
#  'PAY BILL',
#  'SEND MONEY',
#  'UNIDENTIFIED',
#  'CASH WITHDRAWAL CHARGES',
#  'RECEIVED FUNDS',
#  'AIRTIME PURCHASE',
#  'AIRTIME PURCHASE',
#  'SEND MONEY',
#  'RECEIVED FUNDS',
#  'CASH WITHDRAWAL CHARGES',
#  'RECEIVED FUNDS',
#  'PAY BILL CHARGES',
#  'PAY BILL',
#  'UNIDENTIFIED',
#  'AIRTIME PURCHASE',
#  'BUY GOODS',
#  'AIRTIME PURCHASE',
#  'RECEIVED FUNDS',
#  'UNIDENTIFIED',
#  'PAY BILL',
#  'UNIDENTIFIED',
#  'RECEIVED FUNDS',
#  'CASH WITHDRAWAL',
#  'SEND MONEY',
#  'PAY BILL CHARGES',
#  'PAY BILL',
#  'RECEIVED FUNDS',
#  'UNIDENTIFIED',
#  'SEND MONEY',
#  'CASH WITHDRAWAL',
#  'RECEIVED FUNDS',
#  'CASH WITHDRAWAL CHARGES',
#  'CASH WITHDRAWAL',
#  'SEND MONEY',
#  'RECEIVED FUNDS',
#  'SEND MONEY',
#  'PAY BILL CHARGES',
#  'PAY BILL',
#  'RECEIVED FUNDS',
#  'UNIDENTIFIED',
#  'AIRTIME PURCHASE']
